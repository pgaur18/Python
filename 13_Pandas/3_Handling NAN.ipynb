# %%
import pandas as pd
import numpy as np

iris= pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data")
iris
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
df= iris.copy()

df.columns= ["SL", "SW", "PL", "PW", "Flower_Type"]

df.head()
# Out:
#     SL   SW   PL   PW  Flower_Type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  3.1  1.5  0.2  Iris-setosa
# 3  5.0  3.6  1.4  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %% [markdown]
# ### nan is a constant from Numpy
#
# ### How to use it --> np.nan

# %%
df.iloc[ 2:4 , 1:3 ]= np.nan

df.head()
# Out:
#     SL   SW   PL   PW  Flower_Type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  NaN  NaN  0.2  Iris-setosa
# 3  5.0  NaN  NaN  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
print( df.isnull() )

print( df.isnull().sum() )
# Out:
#         SL     SW     PL     PW  Flower_Type
# 0    False  False  False  False        False
# 1    False  False  False  False        False
# 2    False   True   True  False        False
# 3    False   True   True  False        False
# 4    False  False  False  False        False
# ..     ...    ...    ...    ...          ...
# 144  False  False  False  False        False
# 145  False  False  False  False        False
# 146  False  False  False  False        False
# 147  False  False  False  False        False
# 148  False  False  False  False        False
#
# [149 rows x 5 columns]
# SL             0
# SW             2
# PL             2
# PW             0
# Flower_Type    0
# dtype: int64

# %%
df.describe()
# Out:
#                SL          SW          PL          PW
# count  149.000000  147.000000  147.000000  149.000000
# mean     5.848322    3.046939    3.806122    1.205369
# std      0.828594    0.434048    1.750351    0.761292
# min      4.300000    2.000000    1.000000    0.100000
# 25%      5.100000    2.800000    1.600000    0.300000
# 50%      5.800000    3.000000    4.400000    1.300000
# 75%      6.400000    3.300000    5.100000    1.800000
# max      7.900000    4.400000    6.900000    2.500000

# %% [markdown]
# # How to handle NAN values ?
# ## Way 1
#
# ### Drop the Nan entries

# %%
df.dropna(inplace= True)

df
# Out:
#       SL   SW   PL   PW     Flower_Type
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# 5    4.6  3.4  1.4  0.3     Iris-setosa
# 6    5.0  3.4  1.5  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [147 rows x 5 columns]

# %%
df.reset_index(drop= True, inplace= True)

df.head()
# Out:
#     SL   SW   PL   PW  Flower_Type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  5.4  3.9  1.7  0.4  Iris-setosa
# 3  4.6  3.4  1.4  0.3  Iris-setosa
# 4  5.0  3.4  1.5  0.2  Iris-setosa

# %% [markdown]
# ## Assign some value to NaN entries

# %%
df.iloc[2:4, 1:3]= np.nan

df.head()
# Out:
#     SL   SW   PL   PW  Flower_Type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  4.6  NaN  NaN  0.2  Iris-setosa
# 3  5.0  NaN  NaN  0.2  Iris-setosa
# 4  5.4  3.9  1.7  0.4  Iris-setosa

# %%
df.SW.fillna(df.SW.mean(), inplace= True)

df.PL.fillna(df.PL.mean(), inplace= True)

# %%
df.head()
# Out:
#     SL        SW        PL   PW  Flower_Type
# 0  4.9  3.000000  1.400000  0.2  Iris-setosa
# 1  4.7  3.200000  1.300000  0.2  Iris-setosa
# 2  4.6  3.046939  3.806122  0.2  Iris-setosa
# 3  5.0  3.046939  3.806122  0.2  Iris-setosa
# 4  5.4  3.900000  1.700000  0.4  Iris-setosa

# %% [markdown]
# ## Filling it with mean of those type of specific flowers

# %%
# a is a data frame variable. It is same as df
a= df[df.Flower_Type == "Iris-setosa"]

df.SW.fillna(a.SW.mean(), inplace= True)

df.head()


b= df[df.Flower_Type == "Iris-setosa"]

df.PL.fillna(b.PL.mean(), inplace= True)

df.head()
# Out:
#     SL   SW   PL   PW  Flower_Type
# 0  4.9  3.0  1.4  0.2  Iris-setosa
# 1  4.7  3.2  1.3  0.2  Iris-setosa
# 2  5.4  3.9  1.7  0.4  Iris-setosa
# 3  4.6  3.4  1.4  0.3  Iris-setosa
# 4  5.0  3.4  1.5  0.2  Iris-setosa
